# %% [markdown]
# # 🌍🏆 FIFA World Cup Simulation & Prediction
#
# This notebook presents the simulation and prediction workflow for FIFA World Cup scenarios using machine learning models and historical football data.
#
# The focus is to organize the simulation pipeline, prediction flow, and tournament analysis in a professional sports analytics structure without modifying the original notebook logic or content.
#
# ---
#
# ## 📌 Main Objectives
#
# - Simulate FIFA World Cup tournaments
# - Predict football match outcomes
# - Analyze tournament progression
# - Evaluate prediction probabilities
# - Explore football forecasting insights
#
# ---

# %%
# 🎨 Visualization Style Configuration

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["xtick.labelsize"] = 10
plt.rcParams["ytick.labelsize"] = 10

sns.set_theme(style="whitegrid", palette="viridis")

# %% [markdown]
# # ============================================
# # 🌍 FIFA World Cup Project
# # 🏆 World Cup Simulation Engine
# # ============================================
#
# ---

# %% [markdown]
# ## 🤖 Prediction Pipeline
#
# Generating football match predictions using trained models.

# %% [markdown]
# ## 📈 Performance Evaluation
#
# Evaluating prediction and simulation performance.

# %% [markdown]
# ## 📊 Visual Analytics
#
# Exploring simulation insights through visual analysis.

# %%
# ============================================
# 📚 Import Libraries
# ============================================

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import random

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 🗂️ Dataset Preparation
#
# Loading datasets and preparing simulation structures.

# %% [markdown]
# ## 🏆 Tournament Progression Analysis
#
# Analyzing advancement across tournament stages.

# %%
# ============================================
# 📥 Load Final Match Dataset
# ============================================

mmatch_df = pd.read_csv(
    "../data/processed/match_dataset_enhanced.csv"
)

match_df.head()
# Out:
#          date home_team away_team  home_goals  home_goals_conceded  \
# 0  1872-11-30  Scotland   England         0.0                  0.0
# 1  1873-03-08   England  Scotland         4.0                  2.0
# 2  1874-03-07  Scotland   England         2.0                  1.0
# 3  1875-03-06   England  Scotland         2.0                  2.0
# 4  1876-03-04  Scotland   England         3.0                  0.0
#
#    home_goal_difference  home_avg_points_last_5  home_avg_goals_scored_last_5  \
# 0                   0.0                     NaN                           NaN
# 1                   2.0                1.000000                      0.000000
# 2                   1.0                0.500000                      1.000000
# 3                   0.0                1.333333                      1.666667
# 4                   3.0                1.250000                      1.500000
#
#    home_avg_goals_conceded_last_5  home_avg_goal_diff_last_5  ...  \
# 0                             NaN                        NaN  ...
# 1                        0.000000                   0.000000  ...
# 2                        2.000000                  -1.000000  ...
# 3                        1.333333                   0.333333  ...
# 4                        1.750000                  -0.250000  ...
#
#    away_avg_goals_scored_last_5  away_avg_goals_conceded_last_5  \
# 0                           NaN                             NaN
# 1                      0.000000                        0.000000
# 2                      2.000000                        1.000000
# 3                      1.333333                        1.666667
# 4                      1.750000                        1.500000
#
#    away_avg_goal_diff_last_5  away_win_streak  away_clean_sheets_last_5  \
# 0                        NaN              NaN                       NaN
# 1                   0.000000              0.0                       1.0
# 2                   1.000000              1.0                       1.0
# 3                  -0.333333              1.0                       1.0
# 4                   0.250000              1.0                       1.0
#
#    away_momentum_score    target     home_elo     away_elo  elo_difference
# 0                  NaN      Draw  1500.000000  1500.000000        0.000000
# 1             0.500000  Home Win  1500.000000  1500.000000        0.000000
# 2             1.400000  Home Win  1490.000000  1510.000000      -20.000000
# 3             0.733333      Draw  1499.424989  1500.575011       -1.150023
# 4             0.875000  Home Win  1500.541911  1499.458089        1.083822
#
# [5 rows x 27 columns]

# %%
# ============================================
# ⚙️ Feature Selection
# ============================================

features = [

    "home_avg_points_last_5",
    "away_avg_points_last_5",

    "home_avg_goals_scored_last_5",
    "away_avg_goals_scored_last_5",

    "home_avg_goals_conceded_last_5",
    "away_avg_goals_conceded_last_5",

    "home_avg_goal_diff_last_5",
    "away_avg_goal_diff_last_5",

    "home_win_streak",
    "away_win_streak",

    "home_clean_sheets_last_5",
    "away_clean_sheets_last_5",

    "home_momentum_score",
    "away_momentum_score",

    "home_elo",
    "away_elo",

    "elo_difference"
]

X = (
    match_df[features]
    .fillna(0)
)

y = match_df["target"]

# %%
# ============================================
# 🔤 Encode Target
# ============================================

encoder = LabelEncoder()

y_encoded = encoder.fit_transform(y)

# %% [markdown]
# ## 🎮 Tournament Simulation Setup
#
# Configuring the tournament simulation workflow.

# %%
# ============================================
# 🚀 Train Simulation Model
# ============================================

model = GradientBoostingClassifier(

    n_estimators=200,

    learning_rate=0.05,

    max_depth=5,

    random_state=42
)

model.fit(
    X,
    y_encoded
)

print("✅ Simulation model trained.")
# Out:
# ✅ Simulation model trained.

# %%
# ============================================
# 💪 Create Team Strength Table
# ============================================

team_strength = (

    match_df.groupby("home_team")[

        [

            "home_avg_points_last_5",
            "home_avg_goals_scored_last_5",
            "home_avg_goals_conceded_last_5",
            "home_avg_goal_diff_last_5",
            "home_win_streak",
            "home_clean_sheets_last_5",
            "home_momentum_score",
            "home_elo"

        ]

    ]

    .mean()
)

team_strength.head()
# Out:
#              home_avg_points_last_5  home_avg_goals_scored_last_5  \
# home_team
# Abkhazia                   1.812500                      1.700000
# Afghanistan                1.089362                      1.093617
# Albania                    1.049034                      0.966103
# Alderney                   0.500000                      0.858333
# Algeria                    1.641431                      1.537665
#
#              home_avg_goals_conceded_last_5  home_avg_goal_diff_last_5  \
# home_team
# Abkhazia                           0.812500                   0.887500
# Afghanistan                        1.910638                  -0.817021
# Albania                            1.502576                  -0.536473
# Alderney                           3.075000                  -2.216667
# Algeria                            0.998870                   0.538795
#
#              home_win_streak  home_clean_sheets_last_5  home_momentum_score  \
# home_team
# Abkhazia            2.500000                  2.750000             1.766250
# Afghanistan         1.425532                  1.276596             0.603404
# Albania             1.342995                  1.487923             0.676063
# Alderney            0.625000                  0.625000            -0.277500
# Algeria             2.268362                  1.980226             1.469906
#
#                 home_elo
# home_team
# Abkhazia     1541.191497
# Afghanistan  1329.200293
# Albania      1467.993332
# Alderney     1451.796689
# Algeria      1618.397510

# %%
# ============================================
# ⚽ Match Prediction Function
# ============================================

def predict_match(

    home_team,
    away_team
):

    home = team_strength.loc[home_team]
    away = team_strength.loc[away_team]

    input_data = pd.DataFrame({

        "home_avg_points_last_5":
            [home["home_avg_points_last_5"]],

        "away_avg_points_last_5":
            [away["home_avg_points_last_5"]],

        "home_avg_goals_scored_last_5":
            [home["home_avg_goals_scored_last_5"]],

        "away_avg_goals_scored_last_5":
            [away["home_avg_goals_scored_last_5"]],

        "home_avg_goals_conceded_last_5":
            [home["home_avg_goals_conceded_last_5"]],

        "away_avg_goals_conceded_last_5":
            [away["home_avg_goals_conceded_last_5"]],

        "home_avg_goal_diff_last_5":
            [home["home_avg_goal_diff_last_5"]],

        "away_avg_goal_diff_last_5":
            [away["home_avg_goal_diff_last_5"]],

        "home_win_streak":
            [home["home_win_streak"]],

        "away_win_streak":
            [away["home_win_streak"]],

        "home_clean_sheets_last_5":
            [home["home_clean_sheets_last_5"]],

        "away_clean_sheets_last_5":
            [away["home_clean_sheets_last_5"]],

        "home_momentum_score":
            [home["home_momentum_score"]],

        "away_momentum_score":
            [away["home_momentum_score"]],

        "home_elo":
            [home["home_elo"]],

        "away_elo":
            [away["home_elo"]],

        "elo_difference":
            [
                home["home_elo"] -
                away["home_elo"]
            ]
    })

    prediction = model.predict(input_data)[0]

    probabilities = model.predict_proba(input_data)[0]

    result = encoder.inverse_transform(
        [prediction]
    )[0]

    return {

        "match":
            f"{home_team} vs {away_team}",

        "prediction":
            result,

        "home_win_probability":
            round(probabilities[2] * 100, 2),

        "draw_probability":
            round(probabilities[1] * 100, 2),

        "away_win_probability":
            round(probabilities[0] * 100, 2)
    }

# %%
# ============================================
# 🧪 Test Match Prediction
# ============================================

predict_match(
    "Brazil",
    "Argentina"
)
# Out:
# {'match': 'Brazil vs Argentina',
#  'prediction': 'Home Win',
#  'home_win_probability': np.float64(48.73),
#  'draw_probability': np.float64(28.19),
#  'away_win_probability': np.float64(23.07)}

# %%
# ============================================
# 🌍 Simulate Tournament Matches
# ============================================

matches = [

    ("Brazil", "Argentina"),

    ("France", "England"),

    ("Germany", "Spain"),

    ("Portugal", "Netherlands"),

    ("Japan", "South Korea")
]

simulation_results = []

for home, away in matches:

    simulation_results.append(

        predict_match(
            home,
            away
        )
    )

simulation_df = pd.DataFrame(
    simulation_results
)

simulation_df
# Out:
#                      match prediction  home_win_probability  draw_probability  \
# 0      Brazil vs Argentina   Home Win                 48.73             28.19
# 1        France vs England   Home Win                 35.06             30.44
# 2         Germany vs Spain   Home Win                 38.59             29.04
# 3  Portugal vs Netherlands   Home Win                 41.14             28.97
# 4     Japan vs South Korea   Home Win                 40.00             30.73
#
#    away_win_probability
# 0                 23.07
# 1                 34.50
# 2                 32.37
# 3                 29.89
# 4                 29.27

# %%
# ============================================
# 📊 Match Probability Visualization
# ============================================

match = predict_match(
    "Brazil",
    "France"
)

probabilities = [

    match["home_win_probability"],
    match["draw_probability"],
    match["away_win_probability"]
]

labels = [

    "Home Win",
    "Draw",
    "Away Win"
]

plt.figure(figsize=(8,5))

sns.barplot(

    x=labels,

    y=probabilities,

    palette="magma"
)

plt.title(

    f'{match["match"]} Prediction',

    fontsize=18,
    weight="bold"
)

plt.ylabel("Probability (%)")

plt.ylim(0,100)

plt.show()

# %% [markdown]
# # ============================================
# # 💡 Observation
# # ============================================
#
# """
# The match prediction engine uses the improved Gradient Boosting model and enhanced features,
# including rolling team form, momentum indicators, defensive consistency, and Elo-based strength.
#
# The model returns both the predicted outcome and probability distribution for each possible result:
# home win, draw, and away win.
# """
#
# ---

# %% [markdown]
# # ============================================
# # 🏁 Conclusion
# # ============================================
#
# """
# This notebook establishes the first functional simulation engine for the World Cup Predictor project.
#
# The prediction function allows direct comparison between two national teams and provides interpretable
# probabilities for match outcomes. This creates the foundation for future tournament simulation,
# group stage modeling, knockout brackets, and interactive web application integration.
# """
#
# ---
