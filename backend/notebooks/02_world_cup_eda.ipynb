# %% [markdown]
# # 🌍 World Cup Analytics Project
#
# ## FIFA World Cup Tournament Analysis
#
# This notebook presents an exploratory data analysis focused on historical football data, aiming to identify competitive patterns, tournament trends, scoring behaviors, and strategic insights through visual analytics.
#
# ---
#
# ## 📌 Main Objectives
#
# - Understand historical football trends
# - Identify dominant national teams
# - Analyze scoring and match outcome patterns
# - Explore temporal evolution in football competitions
# - Generate insights for future predictive modeling
#
# ---

# %%
# 🎨 Visualization Style Configuration

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["xtick.labelsize"] = 10
plt.rcParams["ytick.labelsize"] = 10

sns.set_theme(style="whitegrid", palette="viridis")

# %% [markdown]
# ## 🏆 Tournament Performance Analysis
#
# Evaluating tournament outcomes and title distribution.

# %%
# 🌍 World Cup Predictor
## FIFA World Cup Exploratory Data Analysis

# %% [markdown]
# # 🎯 Objective
#
#
# The goal of this notebook is to analyze historical FIFA World Cup data,
# identify tournament patterns, explore national team performance,
# and extract insights that may support future predictive models.
#
# This analysis focuses specifically on World Cup matches and tournament history.
#
#
# ---

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

sns.set_style("whitegrid")

# %% [markdown]
# ## 🗂️ Dataset Overview
#
# Initial inspection and validation of the datasets used in this analysis.

# %%
wcmatches = pd.read_csv("../data/raw/wcmatches.csv")
worldcups = pd.read_csv("../data/raw/worldcups.csv")

print("World Cup Matches Shape:", wcmatches.shape)
print("World Cups Shape:", worldcups.shape)
# Out:
# World Cup Matches Shape: (900, 15)
# World Cups Shape: (21, 10)

# %%
wcmatches.head()
# Out:
#    year  country        city    stage  home_team      away_team  home_score  \
# 0  1930  Uruguay  Montevideo  Group 1     France         Mexico           4
# 1  1930  Uruguay  Montevideo  Group 4    Belgium  United States           0
# 2  1930  Uruguay  Montevideo  Group 2     Brazil     Yugoslavia           1
# 3  1930  Uruguay  Montevideo  Group 3       Peru        Romania           1
# 4  1930  Uruguay  Montevideo  Group 1  Argentina         France           1
#
#    away_score outcome win_conditions   winning_team losing_team        date  \
# 0           1       H            NaN         France      Mexico  1930-07-13
# 1           3       A            NaN  United States     Belgium  1930-07-13
# 2           2       A            NaN     Yugoslavia      Brazil  1930-07-14
# 3           3       A            NaN        Romania        Peru  1930-07-14
# 4           0       H            NaN      Argentina      France  1930-07-15
#
#   month dayofweek
# 0   Jul    Sunday
# ...

# %%
worldcups.head()
# Out:
#    year         host        winner          second    third      fourth  \
# 0  1930      Uruguay       Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy         Italy  Czechoslovakia  Germany     Austria
# 2  1938       France         Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil       Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  West Germany         Hungary  Austria     Uruguay
#
#    goals_scored  teams  games  attendance
# 0            70     13     18      434000
# 1            70     16     17      395000
# 2            84     15     18      483000
# 3            88     13     22     1337000
# 4           140     16     26      943000

# %%
wcmatches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            900 non-null    int64
#  1   country         900 non-null    object
#  2   city            900 non-null    object
#  3   stage           900 non-null    object
#  4   home_team       900 non-null    object
#  5   away_team       900 non-null    object
#  6   home_score      900 non-null    int64
#  7   away_score      900 non-null    int64
#  8   outcome         900 non-null    object
#  9   win_conditions  62 non-null     object
#  10  winning_team    731 non-null    object
#  11  losing_team     731 non-null    object
#  12  date            900 non-null    object
#  13  month           900 non-null    object
#  14  dayofweek       900 non-null    object
# dtypes: int64(3), object(12)
# memory usage: 105.6+ KB

# %%
wcmatches.isnull().sum()
# Out:
# year                0
# country             0
# city                0
# stage               0
# home_team           0
# away_team           0
# home_score          0
# away_score          0
# outcome             0
# win_conditions    838
# winning_team      169
# losing_team       169
# date                0
# month               0
# dayofweek           0
# dtype: int64

# %% [markdown]
# ## 📈 Team Performance Analysis
#
# Analyzing team efficiency, win rates, and competitive dominance.

# %%
# 🏆 Most Successful Countries

worldcup_winners = (
    worldcups["winner"]
    .value_counts()
)

worldcup_winners
# Out:
# winner
# Brazil          5
# Italy           4
# West Germany    3
# Uruguay         2
# Argentina       2
# France          2
# England         1
# Spain           1
# Germany         1
# Name: count, dtype: int64

# %%
# 📊 World Cup Winners

plt.figure(figsize=(12,6))
plt.grid(alpha=0.3)

sns.barplot(
    x=worldcup_winners.values,
    y=worldcup_winners.index
)

plt.title("FIFA World Cup Titles by Country")
plt.xlabel("Number of Titles")
plt.ylabel("Country")

plt.show()

plt.tight_layout()

# %% [markdown]
# ## ⚽ Goal Scoring Analysis
#
# Investigating scoring patterns and offensive tendencies.

# %% [markdown]
# ## 📅 Temporal Evolution Analysis
#
# Understanding how football evolved across different eras.

# %% [markdown]
# ## 🌍 Geographical & Continental Analysis
#
# Exploring regional dominance and host nation influence.

# %%
# 🛠️ Adding 2022 World Cup Data

new_row = pd.DataFrame({
    "year": [2022],
    "host": ["Qatar"],
    "winner": ["Argentina"],
    "second": ["France"],
    "third": ["Croatia"],
    "fourth": ["Morocco"],
    "goals_scored": [172],
    "teams": [32],
    "games": [64],
    "attendance": [3404252]
})

worldcups = pd.concat(
    [worldcups, new_row],
    ignore_index=True
)

# %%
worldcup_winners = (
    worldcups["winner"]
    .value_counts()
)

worldcup_winners
# Out:
# winner
# Brazil          5
# Italy           4
# West Germany    3
# Argentina       3
# Uruguay         2
# France          2
# England         1
# Spain           1
# Germany         1
# Name: count, dtype: int64

# %%
# 🇩🇪 Standardizing Germany Names

columns_to_fix = [
    "home_team",
    "away_team",
    "winning_team",
    "losing_team"
]

for col in columns_to_fix:
    wcmatches[col] = wcmatches[col].replace(
        "West Germany",
        "Germany"
    )

# %%
worldcup_winners = (
    worldcups["winner"]
    .value_counts()
)

worldcup_winners
# Out:
# winner
# Brazil          5
# Italy           4
# West Germany    3
# Argentina       3
# Uruguay         2
# France          2
# England         1
# Spain           1
# Germany         1
# Name: count, dtype: int64

# %%
# 📊 FIFA World Cup Titles by Country

plt.figure(figsize=(12,6))
plt.grid(alpha=0.3)

sns.barplot(
    x=worldcup_winners.values,
    y=worldcup_winners.index,
    palette="viridis"
)

plt.title("FIFA World Cup Titles by Country", fontsize=16)
plt.xlabel("Number of Titles", fontsize=12)
plt.ylabel("Country", fontsize=12)

plt.grid(axis="x", linestyle="--", alpha=0.5)

plt.show()

plt.tight_layout()
# Out:
# C:\Users\necca\AppData\Local\Temp\ipykernel_36400\560555651.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# ⚽ Goals Scored per World Cup

goals_per_cup = (
    worldcups[["year", "goals_scored"]]
)

goals_per_cup.head()
# Out:
#    year  goals_scored
# 0  1930            70
# 1  1934            70
# 2  1938            84
# 3  1950            88
# 4  1954           140

# %%
# 📈 Goals Scored in Each World Cup

plt.figure(figsize=(14,6))
plt.grid(alpha=0.3)

sns.lineplot(
    data=goals_per_cup,
    x="year",
    y="goals_scored",
    marker="o"
)

plt.title("Goals Scored per FIFA World Cup")
plt.xlabel("Year")
plt.ylabel("Goals Scored")

plt.show()

# %%
# ⚽ Goals Per Match Calculation

worldcups["goals_per_match"] = (
    worldcups["goals_scored"] /
    worldcups["games"]
)

worldcups[["year", "goals_scored", "games", "goals_per_match"]]
# Out:
#     year  goals_scored  games  goals_per_match
# 0   1930            70     18         3.888889
# 1   1934            70     17         4.117647
# 2   1938            84     18         4.666667
# 3   1950            88     22         4.000000
# 4   1954           140     26         5.384615
# 5   1958           126     35         3.600000
# 6   1962            89     32         2.781250
# 7   1966            89     32         2.781250
# 8   1970            95     32         2.968750
# 9   1974            97     38         2.552632
# 10  1978           102     38         2.684211
# 11  1982           146     52         2.807692
# 12  1986           132     52         2.538462
# 13  1990           115     52         2.211538
# 14  1994           141     52         2.711538
# 15  1998           171     64         2.671875
# 16  2002           161     64         2.515625
# 17  2006           147     64         2.296875
# 18  2010           145     64         2.265625
# ...

# %%
# 📈 Average Goals Per Match by World Cup

plt.figure(figsize=(14,6))
plt.grid(alpha=0.3)

sns.lineplot(
    data=worldcups,
    x="year",
    y="goals_per_match",
    marker="o",
    color="green",
    linewidth=2.5
)

plt.title("Average Goals Per Match in FIFA World Cups")
plt.xlabel("Year")
plt.ylabel("Goals Per Match")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# # 📌 Key Insights
#
#
# - Earlier FIFA World Cups were significantly more offensive, with very high average goals per match.
# - The 1954 World Cup stands out as one of the highest-scoring tournaments in history.
# - After the mid-20th century, average goals per match declined considerably and became more stable.
# - Modern World Cups typically maintain averages between 2 and 3 goals per match.
# - This trend may reflect tactical evolution, stronger defensive systems,
#   increased competitiveness, and improved physical preparation in modern football.
# - Recent tournaments show slight offensive recovery, suggesting a more dynamic modern playing style.
#
#
# ---

# %%
# 🏟️ Host Country vs World Cup Winner

worldcups[["year", "host", "winner"]]
# Out:
#     year                host        winner
# 0   1930             Uruguay       Uruguay
# 1   1934               Italy         Italy
# 2   1938              France         Italy
# 3   1950              Brazil       Uruguay
# 4   1954         Switzerland  West Germany
# 5   1958              Sweden        Brazil
# 6   1962               Chile        Brazil
# 7   1966             England       England
# 8   1970              Mexico        Brazil
# 9   1974             Germany  West Germany
# 10  1978           Argentina     Argentina
# 11  1982               Spain         Italy
# 12  1986              Mexico     Argentina
# 13  1990               Italy  West Germany
# 14  1994                 USA        Brazil
# 15  1998              France        France
# 16  2002  Japan, South Korea        Brazil
# 17  2006             Germany         Italy
# 18  2010        South Africa         Spain
# 19  2014              Brazil       Germany
# 20  2018              Russia        France
# ...

# %%
# 🏆 Did the Host Country Win?

worldcups["host_winner"] = (
    worldcups["host"] == worldcups["winner"]
)

worldcups[["year", "host", "winner", "host_winner"]]
# Out:
#     year                host        winner  host_winner
# 0   1930             Uruguay       Uruguay         True
# 1   1934               Italy         Italy         True
# 2   1938              France         Italy        False
# 3   1950              Brazil       Uruguay        False
# 4   1954         Switzerland  West Germany        False
# 5   1958              Sweden        Brazil        False
# 6   1962               Chile        Brazil        False
# 7   1966             England       England         True
# 8   1970              Mexico        Brazil        False
# 9   1974             Germany  West Germany        False
# 10  1978           Argentina     Argentina         True
# 11  1982               Spain         Italy        False
# 12  1986              Mexico     Argentina        False
# 13  1990               Italy  West Germany        False
# 14  1994                 USA        Brazil        False
# 15  1998              France        France         True
# ...

# %%
# 📊 Number of Host Winners

host_wins = worldcups["host_winner"].value_counts()

host_wins
# Out:
# host_winner
# False    17
# True      5
# Name: count, dtype: int64

# %%
# 📈 Host Country World Cup Wins

plt.figure(figsize=(8,5))
plt.grid(alpha=0.3)

sns.barplot(
    x=host_wins.index.astype(str),
    y=host_wins.values,
    hue=host_wins.index.astype(str),
    palette="crest",
    legend=False
)

plt.title("Did Host Countries Win the World Cup?")
plt.xlabel("Host Won Tournament")
plt.ylabel("Count")

plt.grid(axis="y", alpha=0.3)

plt.show()

plt.tight_layout()

# %%
# 🥇 Host Country Top 4 Analysis

worldcups["host_top4"] = (
    (worldcups["host"] == worldcups["winner"]) |
    (worldcups["host"] == worldcups["second"]) |
    (worldcups["host"] == worldcups["third"]) |
    (worldcups["host"] == worldcups["fourth"])
)

worldcups[["year", "host", "host_top4"]]
# Out:
#     year                host  host_top4
# 0   1930             Uruguay       True
# 1   1934               Italy       True
# 2   1938              France      False
# 3   1950              Brazil       True
# 4   1954         Switzerland      False
# 5   1958              Sweden       True
# 6   1962               Chile       True
# 7   1966             England       True
# 8   1970              Mexico      False
# 9   1974             Germany      False
# 10  1978           Argentina       True
# 11  1982               Spain      False
# 12  1986              Mexico      False
# 13  1990               Italy       True
# 14  1994                 USA      False
# 15  1998              France       True
# 16  2002  Japan, South Korea      False
# 17  2006             Germany       True
# 18  2010        South Africa      False
# 19  2014              Brazil       True
# 20  2018              Russia      False
# 21  2022               Qatar      False

# %%
# 📊 Host Top 4 Count

host_top4_counts = (
    worldcups["host_top4"]
    .value_counts()
)

host_top4_counts
# Out:
# host_top4
# True     11
# False    11
# Name: count, dtype: int64

# %%
# 📈 Host Countries Reaching Top 4

plt.figure(figsize=(8,5))
plt.grid(alpha=0.3)

sns.barplot(
    x=host_top4_counts.index.astype(str),
    y=host_top4_counts.values,
    hue=host_top4_counts.index.astype(str),
    palette="viridis",
    legend=False
)

plt.title("Did Host Countries Reach Top 4?")
plt.xlabel("Host Reached Top 4")
plt.ylabel("Count")

plt.grid(axis="y", alpha=0.3)

plt.show()

plt.tight_layout()

# %% [markdown]
# # 📌 Key Insights
#
#
# - Host countries do not frequently win the FIFA World Cup, but they often achieve strong tournament performances.
# - Approximately half of the host nations reached the Top 4 positions in World Cup history.
# - These findings suggest that hosting the tournament may provide a meaningful competitive advantage.
# - Possible factors include crowd support, reduced travel fatigue, climate familiarity,
#   and psychological confidence associated with playing at home.
# - Host nation influence may become an important feature in future predictive modeling stages.
#
#
# ---

# %%
# 🌍 Country to Continent Mapping

continent_map = {
    "Brazil": "South America",
    "Argentina": "South America",
    "Uruguay": "South America",

    "Germany": "Europe",
    "Italy": "Europe",
    "France": "Europe",
    "England": "Europe",
    "Spain": "Europe"
}

# %%
# 🌍 Winner Continents

worldcups["winner_continent"] = (
    worldcups["winner"]
    .map(continent_map)
)

worldcups[["year", "winner", "winner_continent"]]
# Out:
#     year        winner winner_continent
# 0   1930       Uruguay    South America
# 1   1934         Italy           Europe
# 2   1938         Italy           Europe
# 3   1950       Uruguay    South America
# 4   1954  West Germany              NaN
# 5   1958        Brazil    South America
# 6   1962        Brazil    South America
# 7   1966       England           Europe
# 8   1970        Brazil    South America
# 9   1974  West Germany              NaN
# 10  1978     Argentina    South America
# 11  1982         Italy           Europe
# 12  1986     Argentina    South America
# 13  1990  West Germany              NaN
# 14  1994        Brazil    South America
# 15  1998        France           Europe
# 16  2002        Brazil    South America
# 17  2006         Italy           Europe
# 18  2010         Spain           Europe
# 19  2014       Germany           Europe
# 20  2018        France           Europe
# 21  2022     Argentina    South America

# %%
# 📊 World Cup Titles by Continent

continent_titles = (
    worldcups["winner_continent"]
    .value_counts()
)

continent_titles
# Out:
# winner_continent
# South America    10
# Europe            9
# Name: count, dtype: int64

# %%
# 📈 Continental Dominance

plt.figure(figsize=(10,6))
plt.grid(alpha=0.3)

sns.barplot(
    x=continent_titles.index,
    y=continent_titles.values,
    hue=continent_titles.index,
    palette="Spectral",
    legend=False
)

plt.title("FIFA World Cup Titles by Continent")
plt.xlabel("Continent")
plt.ylabel("Number of Titles")

plt.grid(axis="y", alpha=0.3)

plt.show()

plt.tight_layout()

# %%
# 📈 Continental Winners Through Time

plt.figure(figsize=(14,6))
plt.grid(alpha=0.3)

sns.scatterplot(
    data=worldcups,
    x="year",
    y="winner_continent",
    hue="winner_continent",
    palette="Spectral",
    s=150
)

plt.title("World Cup Winners by Continent Through Time")
plt.xlabel("Year")
plt.ylabel("Continent")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# # 📌 Key Insights
#
#
# - Europe currently holds the highest number of FIFA World Cup titles,
#   although the difference compared to South America remains relatively small.
# - Early World Cup history showed stronger South American dominance,
#   while Europe became increasingly dominant in modern tournaments.
# - The competitive balance between Europe and South America highlights
#   the historical concentration of elite football nations within these two continents.
# - Modern European dominance may be associated with stronger domestic leagues,
#   infrastructure investment, tactical evolution, and player development systems.
# - Despite fewer titles, South America maintains remarkable historical efficiency
#   with relatively few countries consistently competing at the highest level.
#
#
# ---

# %% [markdown]
# ## ⚔️ Matchup & Finals Analysis
#
# Identifying recurring rivalries and historical final matchups.

# %%
# ⚔️ Creating Matchup Identifier

wcmatches["matchup"] = (
    wcmatches[["home_team", "away_team"]]
    .apply(lambda x: " vs ".join(sorted(x)), axis=1)
)

wcmatches[["home_team", "away_team", "matchup"]].head()
# Out:
#    home_team      away_team                   matchup
# 0     France         Mexico          France vs Mexico
# 1    Belgium  United States  Belgium vs United States
# 2     Brazil     Yugoslavia      Brazil vs Yugoslavia
# 3       Peru        Romania           Peru vs Romania
# 4  Argentina         France       Argentina vs France

# %%
# 📊 Most Frequent Matchups

top_matchups = (
    wcmatches["matchup"]
    .value_counts()
    .head(10)
)

top_matchups
# Out:
# matchup
# Brazil vs Sweden            7
# Argentina vs Germany        7
# Brazil vs Italy             5
# Germany vs Sweden           5
# Brazil vs Czechoslovakia    5
# Brazil vs Mexico            5
# Argentina vs Netherlands    5
# Argentina vs England        5
# Argentina vs Nigeria        5
# Germany vs Italy            5
# Name: count, dtype: int64

# %%
# 📈 Top 10 World Cup Matchups

plt.figure(figsize=(14,6))
plt.grid(alpha=0.3)

sns.barplot(
    x=top_matchups.values,
    y=top_matchups.index,
    hue=top_matchups.index,
    palette="rocket",
    legend=False
)

plt.title("Top 10 Most Frequent World Cup Matchups")
plt.xlabel("Number of Matches")
plt.ylabel("Matchup")

plt.grid(axis="x", alpha=0.3)

plt.show()

plt.tight_layout()

# %%
# 🏆 World Cup Finals Only

final_matches = (
    wcmatches[wcmatches["stage"] == "Final"]
)

final_matches[["year", "home_team", "away_team"]]
# Out:
#      year    home_team       away_team
# 17   1930      Uruguay       Argentina
# 34   1934        Italy  Czechoslovakia
# 52   1938      Hungary           Italy
# 100  1954      Germany         Hungary
# 135  1958       Sweden          Brazil
# 167  1962       Brazil  Czechoslovakia
# 199  1966      England         Germany
# 231  1970       Brazil           Italy
# 269  1974      Germany     Netherlands
# 307  1978    Argentina     Netherlands
# 359  1982        Italy         Germany
# 411  1986    Argentina         Germany
# 463  1990      Germany       Argentina
# 515  1994       Brazil           Italy
# 579  1998       France          Brazil
# 643  2002      Germany          Brazil
# 707  2006        Italy          France
# 771  2010  Netherlands           Spain
# 835  2014      Germany       Argentina
# 899  2018       France         Croatia

# %%
# ⚔️ Most Frequent Final Matchups

final_matches["final_matchup"] = (
    final_matches[["home_team", "away_team"]]
    .apply(lambda x: " vs ".join(sorted(x)), axis=1)
)

top_final_matchups = (
    final_matches["final_matchup"]
    .value_counts()
)

top_final_matchups
# Out:
# C:\Users\necca\AppData\Local\Temp\ipykernel_36400\2125958724.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_matches["final_matchup"] = (
# final_matchup
# Argentina vs Germany        3
# Brazil vs Italy             2
# Argentina vs Uruguay        1
# Germany vs Hungary          1
# Czechoslovakia vs Italy     1
# Brazil vs Sweden            1
# Brazil vs Czechoslovakia    1
# England vs Germany          1
# Hungary vs Italy            1
# Germany vs Netherlands      1
# Argentina vs Netherlands    1
# Germany vs Italy            1
# Brazil vs France            1
# Brazil vs Germany           1
# France vs Italy             1
# Netherlands vs Spain        1
# Croatia vs France           1
# Name: count, dtype: int64

# %%
# 📈 Most Frequent World Cup Finals

plt.figure(figsize=(12,5))
plt.grid(alpha=0.3)

sns.barplot(
    x=top_final_matchups.values,
    y=top_final_matchups.index,
    hue=top_final_matchups.index,
    palette="magma",
    legend=False
)

plt.title("Most Frequent FIFA World Cup Finals")
plt.xlabel("Number of Finals")
plt.ylabel("Final Matchup")

plt.grid(axis="x", alpha=0.3)

plt.show()

plt.tight_layout()

# %%
# 🇩🇪 Standardizing Germany Names

columns_to_fix = [
    "home_team",
    "away_team",
    "winning_team",
    "losing_team"
]

for col in columns_to_fix:
    wcmatches[col] = wcmatches[col].replace(
        "West Germany",
        "Germany"
    )

# %%
# ⚔️ Rebuilding Matchups

wcmatches["matchup"] = (
    wcmatches[["home_team", "away_team"]]
    .apply(lambda x: " vs ".join(sorted(x)), axis=1)
)

top_matchups = (
    wcmatches["matchup"]
    .value_counts()
    .head(10)
)

top_matchups
# Out:
# matchup
# Brazil vs Sweden            7
# Argentina vs Germany        7
# Brazil vs Italy             5
# Germany vs Sweden           5
# Brazil vs Czechoslovakia    5
# Brazil vs Mexico            5
# Argentina vs Netherlands    5
# Argentina vs England        5
# Argentina vs Nigeria        5
# Germany vs Italy            5
# Name: count, dtype: int64

# %%
# 🏆 Rebuilding Final Matchups

final_matches = (
    wcmatches[wcmatches["stage"] == "Final"]
)

final_matches["final_matchup"] = (
    final_matches[["home_team", "away_team"]]
    .apply(lambda x: " vs ".join(sorted(x)), axis=1)
)

top_final_matchups = (
    final_matches["final_matchup"]
    .value_counts()
)

top_final_matchups
# Out:
# C:\Users\necca\AppData\Local\Temp\ipykernel_36400\3532629418.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_matches["final_matchup"] = (
# final_matchup
# Argentina vs Germany        3
# Brazil vs Italy             2
# Argentina vs Uruguay        1
# Germany vs Hungary          1
# Czechoslovakia vs Italy     1
# Brazil vs Sweden            1
# Brazil vs Czechoslovakia    1
# England vs Germany          1
# Hungary vs Italy            1
# Germany vs Netherlands      1
# Argentina vs Netherlands    1
# Germany vs Italy            1
# Brazil vs France            1
# Brazil vs Germany           1
# France vs Italy             1
# Netherlands vs Spain        1
# Croatia vs France           1
# Name: count, dtype: int64

# %% [markdown]
# # 📌 Key Insights
#
#
# - Historical inconsistencies were identified between different datasets,
#   particularly regarding the use of 'West Germany' and 'Germany'.
# - Standardizing historical country names was necessary to ensure accurate matchup aggregation.
# - Data consistency across datasets is essential for reliable statistical analysis
#   and future predictive modeling tasks.
#
#
# ---
